# %%
import pandas as pd  
import numpy as np 
import plotly.express as px

# %%
df = pd.read_excel('Book.xlsx')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df['first name']
# Out:
# 0        ram
# 1      vijay
# 2      imran
# 3       ajay
# 4      vijay
# 5      rohan
# 6    vidhya
# 7      suraj
# 8      arjun
# 9    arun kr
# Name: first name, dtype: object

# %%
df[['first name','last name']]
# Out:
#   first name last name
# 0        ram    sharma
# 1      vijay    pandey
# 2      imran       ali
# 3       ajay    pandey
# 4      vijay    sharma
# 5      rohan    kapoor
# 6    vidhya      singh
# 7      suraj     singh
# 8      arjun    kapoor
# 9    arun kr    pandey

# %%
df.iloc[-1]
# Out:
# id                    10
# first name       arun kr
# last name         pandey
# basic salary       30000
# d.a                  0.4
# H.r.a                0.8
# t.a                  0.1
# department      purchase
#      fine            299
# Name: 9, dtype: object

# %%
df.iloc[-1].tolist()
# Out:
# [10, 'arun kr', 'pandey', 30000, 0.4, 0.8, 0.1, 'purchase', 299]

# %%
df.iloc[-5:] #last 5 rows
# Out:
#    id first name last name  basic salary  d.a  H.r.a  t.a department  \
# 5   6      rohan    kapoor         50000  0.3    0.8  0.1        rnd
# 6   7    vidhya      singh         52000  0.4    0.8  0.1      sales
# 7   8      suraj     singh         95000  0.4    1.0  0.5   purchase
# 8   9      arjun    kapoor         10000  0.3    0.6  0.1        rnd
# 9  10    arun kr    pandey         30000  0.4    0.8  0.1   purchase
#
#         fine
# 5          0
# 6          0
# 7        299
# 8        299
# 9        299

# %%
df.iloc[-5:,:3]
# Out:
#    id first name last name
# 5   6      rohan    kapoor
# 6   7    vidhya      singh
# 7   8      suraj     singh
# 8   9      arjun    kapoor
# 9  10    arun kr    pandey

# %%
df
# Out:
#    id first name last name  basic salary  d.a  H.r.a  t.a department  \
# 0   1        ram    sharma         30000  0.5    0.8  0.1      sales
# 1   2      vijay    pandey         25000  0.3    0.8  0.1   purchase
# 2   3      imran       ali         45000  0.4    0.8  0.1        rnd
# 3   4       ajay    pandey         25000  0.4    0.8  0.1      sales
# 4   5      vijay    sharma         19500  0.5    0.6  0.1   purchase
# 5   6      rohan    kapoor         50000  0.3    0.8  0.1        rnd
# 6   7    vidhya      singh         52000  0.4    0.8  0.1      sales
# 7   8      suraj     singh         95000  0.4    1.0  0.5   purchase
# 8   9      arjun    kapoor         10000  0.3    0.6  0.1        rnd
# 9  10    arun kr    pandey         30000  0.4    0.8  0.1   purchase
#
#         fine
# 0        600
# 1        299
# 2        588
# 3       1020
# 4        399
# 5          0
# 6          0
# 7        299
# 8        299
# 9        299

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10 non-null     int64
#  1   first name    10 non-null     object
#  2   last name     10 non-null     object
#  3   basic salary  10 non-null     int64
#  4   d.a           10 non-null     float64
#  5   H.r.a         10 non-null     float64
#  6   t.a           10 non-null     float64
#  7   department    10 non-null     object
#  8        fine     10 non-null     int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 848.0+ bytes

# %%
df.describe()
# Out:
#              id  basic salary        d.a      H.r.a        t.a         fine
# count  10.00000     10.000000  10.000000  10.000000  10.000000    10.000000
# mean    5.50000  38150.000000   0.390000   0.780000   0.140000   380.300000
# std     3.02765  24106.303924   0.073786   0.113529   0.126491   301.232302
# min     1.00000  10000.000000   0.300000   0.600000   0.100000     0.000000
# 25%     3.25000  25000.000000   0.325000   0.800000   0.100000   299.000000
# 50%     5.50000  30000.000000   0.400000   0.800000   0.100000   299.000000
# 75%     7.75000  48750.000000   0.400000   0.800000   0.100000   540.750000
# max    10.00000  95000.000000   0.500000   1.000000   0.500000  1020.000000

# %%
df.head(3)
# Out:
#    id first name last name  basic salary  d.a  H.r.a  t.a department  \
# 0   1        ram    sharma         30000  0.5    0.8  0.1      sales
# 1   2      vijay    pandey         25000  0.3    0.8  0.1   purchase
# 2   3      imran       ali         45000  0.4    0.8  0.1        rnd
#
#         fine
# 0        600
# 1        299
# 2        588

# %%
df['d.a']
# Out:
# 0    0.5
# 1    0.3
# 2    0.4
# 3    0.4
# 4    0.5
# 5    0.3
# 6    0.4
# 7    0.4
# 8    0.3
# 9    0.4
# Name: d.a, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'first name', 'last name', 'basic salary', 'd.a', 'H.r.a', 't.a',
#        'department', '     fine'],
#       dtype='object')
